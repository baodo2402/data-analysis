# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn_linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 5
#       3 import seaborn as sns
#       4 import numpy as np
# ----> 5 from sklearn_linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn_linear_model'

# %%
# !pip install numpy scipy scikit-learn

# %%
df = pd.read_csv('Spotify.csv')
df
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy
# 0              0       0.01020         0.833       204600   0.434  \
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %% [markdown]
# # Top 5 most popular artists

# %%
top_five_artists = df.groupby('artist').count().sort_values(by='song_title', ascending=False)['song_title'][:5]
top_five_artists
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# Backstreet Boys    10
# WALK THE MOON      10
# Name: song_title, dtype: int64

# %%
df.groupby('artist').count()
# Out:
#                    Unnamed: 0  acousticness  danceability  duration_ms
# artist
# !!!                         1             1             1            1  \
# *NSYNC                      8             8             8            8
# 10cm                        2             2             2            2
# 2 Chainz                    3             3             3            3
# 2 LIVE CREW                 1             1             1            1
# ...                       ...           ...           ...          ...
# tobyMac                     1             1             1            1
# 권나무 Kwon Tree               1             1             1            1
# 도시총각 Dosichonggak           1             1             1            1
# 카우칩스 The CowChips           1             1             1            1
# 플랫핏 Flat Feet               1             1             1            1
#
#                    energy  instrumentalness  key  liveness  loudness  mode
# artist
# ...

# %%
df['artist'].value_counts()[:5]
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# WALK THE MOON      10
# Backstreet Boys    10
# Name: count, dtype: int64

# %%
top_five_artists.plot.barh()
plt.show()

# %% [markdown]
# # top 5 loudest tracks

# %%
top_five_loudest = df[['loudness', 'song_title']].sort_values(by='loudness', ascending=True)[:5]
top_five_loudest
# Out:
#       loudness                                         song_title
# 1594   -33.097            Lyric Pieces, Book I Op. 12: I. Arietta
# 1596   -31.367            8 Fantasiestücke, Op.12 : 1. Des Abends
# 1598   -31.082  Piano Quartet in E flat, Op.47: 3. Andante can...
# 1531   -30.447          I Was So Young, and You Were So Beautiful
# 1549   -29.460                                            Eleanor

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='loudness', y='song_title', data=top_five_loudest)
plt.title('Top five loudest songs')
plt.show()

# %% [markdown]
# # Artist with the most danceability song

# %%
top_five_artists_danceable_songs = df[['danceability','song_title','artist']].sort_values(by='danceability',ascending=False)[:5]
top_five_artists_danceable_songs
# Out:
#       danceability              song_title             artist
# 1433         0.984  Flashwind - Radio Edit       Ben Remember
# 1901         0.967                SexyBack  Justin Timberlake
# 604          0.962       Check Me Out Like          Blaqstarr
# 32           0.959             Best Friend         Young Thug
# 1957         0.959            Ice Ice Baby        Vanilla Ice

# %%
plt.figure(figsize=(12, 7))
sns.barplot(x = "danceability", y = 'artist', data=top_five_artists_danceable_songs)
plt.title("danceability")
plt.show()

# %% [markdown]
# # top five instrumentalist tracks

# %%
df.head(2)
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy
# 0           0        0.0102         0.833       204600   0.434  \
# 1           1        0.1990         0.743       326933   0.359
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo
# 0           0.02190    2     0.165    -8.795     1       0.4310  150.062  \
# 1           0.00611    1     0.137   -10.401     1       0.0794  160.083
#
#    time_signature  valence  target song_title            artist
# 0             4.0    0.286       1   Mask Off            Future
# 1             4.0    0.588       1    Redbone  Childish Gambino

# %%
top_five_instrumentalness_tracks = df[['instrumentalness','song_title']].sort_values(by='instrumentalness', ascending = False)[:5]
top_five_instrumentalness_tracks
# Out:
#       instrumentalness                            song_title
# 1313             0.976                       Senseless Order
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)

# %%
df['instrumentalness'].value_counts()
# Out:
# instrumentalness
# 0.000000    693
# 0.897000      5
# 0.878000      4
# 0.425000      3
# 0.001280      3
#            ...
# 0.642000      1
# 0.000060      1
# 0.043900      1
# 0.002170      1
# 0.000039      1
# Name: count, Length: 1107, dtype: int64
